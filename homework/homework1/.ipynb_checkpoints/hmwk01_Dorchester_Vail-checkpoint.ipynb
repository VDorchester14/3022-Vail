# %% [markdown]
# # Homework 1: Data Cleaning and Exploratory Data Analysis
# ***
#
# **Name**:
#
# ***
#
# This assignment is due on Moodle by **5pm on Friday February 2nd**. Your solutions to theoretical questions should be done in Markdown directly below the associated question.  Your solutions to computational questions should include any specified Python code and results as well as written commentary on your conclusions.  Remember that you are encouraged to discuss the problems with your classmates, but **you must write all code and solutions on your own**.
#
# **NOTES**:
#
# - Unless a url is given for a data set, you will find the required data in the same directory as this assignment on GitHub.
# - If you're not familiar with typesetting math directly into Markdown then by all means, do your work on paper first and then typeset it later.  Remember that there is a [reference guide](https://math.meta.stackexchange.com/questions/5020/mathjax-basic-tutorial-and-quick-reference) linked on Piazza on writing math in Markdown.
# - It is **bad form** to make your reader interpret numerical output from your code.  If a question asks you to compute some value from the data you should show your code output **AND** write a summary of the results in Markdown directly below your code.

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline

# %% [markdown]
# ### Problem 1
# ***
#
# An owner of an animal sanctuary wants to estimate her sanctuary's average food consumption over the next year in order to estimate the future food costs. Her sanctuary comprises 75 pandas, 25 otters, 50 buffalo, and 50 owls. The owner pops open her SanctuaryTrackr App's Current Resident List, randomly selects 24 animals from it, and tracks their food consumptions in pounds per day (lbs/day) over the next week. So as to get a good estimate, she intentionally selects 9 pandas, 3 otters, 6 buffalo, and 6 owls.
#
# Identify the following:
#
# - the population
# - the sample frame
# - the sample
# - the type of sample
# - the quantity of interest

# %% [markdown]
# Population: The animals in her sanctuary<br>
# Sample frame: The SanctuaryTrackr App Current Resident List<br>
# sample: The 24 animals she chose <br>
# type of sample: A stratified sample <br>
# quantity of interest: Average food consumption in the sanctuary per year.

# %% [markdown]
# ### Problem 2
# ***
#
# A method to investigate the sensitivity of the sample mean and the sample median to extreme outliers is to replace one or more elements in a given dataset by a number $y$ and investigate the eﬀect when $y$ goes to inﬁnity. To illustrate this, consider the dataset
#
# $$
# 4.6 \quad
# 5.0 \quad
# 6.5 \quad
# 7.7 \quad
# 3.2 \quad
# 4.2 \quad
# 3.0 \quad
# 6.6
# $$
#
# **Part A**: Compute the sample mean and sample median.

# %%
#making the array
s = np.array([4.6,5.0,6.5,7.7,3.2,4.2,3.0,6.6])
s = np.sort(s)
print(s)
print('Mean: '+str(s.mean()))
print('Median: '+str(np.median(s)))
# Out:
# [ 3.   3.2  4.2  4.6  5.   6.5  6.6  7.7]
# Mean: 5.1
# Median: 4.8

# %% [markdown]
# **Part B**: We replace the element $5.0$ by some real number $q$. What happens with the sample mean and the sample median of this new dataset as $q \rightarrow -\infty$?

# %% [markdown]
# The mean will start to approach -infinity, and the median will tend towards 4.4

# %% [markdown]
# **Part C**: We replace a number of elements by some real number $q$. How many elements do we need to replace so that the sample median of the new dataset goes to infinity as $q \rightarrow -\infty$?

# %% [markdown]
# The sample median would not approach infinity in this scenario. Even if you replaced every value with q, the median would then just be negative infinity and not positive infinity. to get the median to approach negative infinity, you'd just have to replace the first 4 values so that the median was the average of the middle two (even number of elements), which would be -infinity and 5.

# %% [markdown]
# **Part D**: Suppose we have another data set of size $n$. How many elements do we need to replace by some real number $q$, so that the sample mean of the new dataset diverges as $q \rightarrow -\infty$? And how many elements do we need to replace, so that the sample median of the new dataset goes to infinity?

# %% [markdown]
# I think just one because the series is divergent if the limit doesn't exist or goes to negative infinity or positive infinity, and if one value is infinity, then the limit approaches infinity as well. As for the median, then it would need to be n/2 for even n and ceiling(n/2) for odd n.

# %% [markdown]
# ### Problem 3
# ***
#
# Let $x_1, x_2, \ldots, x_n$ be $n$ observations of a variable of interest.  Recall that the sample mean $\bar{x}_n$ and sample variance $s^2_n$ are given by
#
# $$
# \bar{x}_n = \frac{1}{n}\sum_{k=1}^n x_k \quad \textrm{and} \quad s^2_n = \frac{1}{n-1}\sum_{k=1}^n \left( x_k - \bar{x}_n\right)^2
# $$
#
# where here the subscript $n$'s indicate the number of observations in the sample. Notice that a natural computation of the variance requires two passes over the data: one to compute the mean, and a second to subtract the mean from each observation and compute the sum of squares. It is often useful to be able to compute the variance in a single pass, inspecting each value $x_k$ only once; for example, when the data are being collected without enough storage to keep all the values, or when costs of memory access dominate those of computation. In this problem you will explore two methods for such an _online_ computation of the mean and variance.
#
# **Part A**: Show algebraically that the following relation holds between the mean of the first $n-1$ observations and the mean of all $n$ observations:
#
# $$
# \bar{x}_n = \bar{x}_{n-1} + \frac{x_n - \bar{x}_{n-1}}{n}
# $$

# %% [markdown]
# **Part B**: Write a function `my_sample_mean` that takes as its input a numpy array and returns the mean of that numpy array using the formulas from class (written above). You may *not* use numpy's built in mean function. Write another function `my_sample_var` that takes as its input a numpy array and returns the variance of that numpy array, again using the formulas from class (written above). You may *not* use any built-in sample variance functions.

# %%
def my_sample_mean(arr):
    mean = 0
    for i in np.nditer(arr):
        mean = mean + i
    return mean/arr.shape[0]
def my_sample_var(arr):
    mean = my_sample_mean(arr)
    var = 0
    for i in np.nditer(arr):
        var =  var + (i - mean)**2
    return var/(arr.shape[0] - 1)

# %% [markdown]
# **Part C**: Use your functions from Part B to compute the sample mean and sample variance of the following array.
#
# `otter_weights = [25, 29, 40, 19, 7, 6, 3, 12, 19, 21, 22, 45, 27]`

# %%
otter_weights = np.array([25, 29, 40, 19, 7, 6, 3, 12, 19, 21, 22, 45, 27])
print("Mean: "+str(my_sample_mean(otter_weights)))
print("Variance: "+str(my_sample_var(otter_weights)))
# Out:
# Mean: 21.1538461538
# Variance: 157.307692308

# %% [markdown]
# **Part D**: Implement a third function called `update_mean` that implements the formula whose valdity you proved in Part A. (Note: this function will need to take as its input three things: $x_n$, $\bar{x}_{n-1}$ and $n$.)
#
# Use this function to compute the values that you get from taking the mean of the first one otter, the first two otters, the first three otters, and so on up to all the otters. Store your otter means in a numpy array called `otterations`.

# %%
otterations = np.array([])
def update_mean(xn, xn1, n):
    return (xn1 + ((xn - xn1)/(n)))

#first otter
val = update_mean(otter_weights[0], 0, 1)
otterations = np.append(otterations, val)

#second otter
val = update_mean(otter_weights[1], 25, 2)
otterations = np.append(otterations, val)

#using it to get rest of otters
for n in range(2, otter_weights.shape[0]):
    val = update_mean(otter_weights[n], my_sample_mean(otter_weights[0:n-1]), n+1)
    otterations = np.append(otterations, val)

#print values
for n in np.nditer(otterations):
    print(n)
# Out:
# 25.0
# 27.0
# 30.0
# 25.0
# 26.466666666666665
# 24.541666666666668
# 21.0
# 19.875
# 18.49206349206349
# 17.9625
# 18.161616161616163
# 20.34166666666667
# 19.11188811188811

# %% [markdown]
# ### Problem 4
# ***
# Some claim that the final hours aboard the RMS Titanic were marked by class warfare; others claim it was characterized by male chivalry.  We have the data on survival rates by class and by sex, so let's figure out whether there is evidence for these scenarios. Access the titanic data in `titanic_data.csv` and store it in a Pandas DataFrame. The data contains information pertaining to class status (**Pclass**), survival of passengers (**Survived**), and gender (**Sex**), among others.

# %% [markdown]
# **Part A**: Consider the two claims: class warfare, and male chivalry. Suppose that class warfare occurred in the final hours aboard the Titanic.  What patterns might you expect to see in the data?  Suppose that male chivalry was widespread during the final hours insteas. What patterns might you then expect to see in the data?  Explain both of these hypothesized patterns in words. Are these two hypotheses mutually exclusive or not?

# %%
path = 'titanic_data.csv'
df = pd.read_csv(path)
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  36.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  18.0      1
# 2                             Heikkinen, Miss. Laina  female  14.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  27.0      1
# 4                           Allen, Mr. William Henry    male  63.0      0
# 5                                   Moran, Mr. James    male  14.0      0
# 6                            McCarthy, Mr. Timothy J    male  39.0      0
# 7                     Palsson, Master. Gosta Leonard    male   NaN      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female   NaN      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female   NaN      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %% [markdown]
# **Part B**: Create a clean data set by removing any rows from the DataFrame that are missing values corresponding to **Survived**, **Pclass**, **Age**, or **Sex**. Store the clean data in a DataFrame called dfTitanic.

# %%
#replace empty strings with NaN
df["Survived"].replace('', np.nan, inplace=True)
df["Pclass"].replace('', np.nan, inplace=True)
df["Age"].replace('', np.nan, inplace=True)
df["Sex"].replace('', np.nan, inplace=True)
#now drop the NaN
df.dropna(subset=['Survived'], inplace=True)
df.dropna(subset=['Pclass'], inplace=True)
df.dropna(subset=['Age'], inplace=True)
df.dropna(subset=['Sex'], inplace=True)
#now check
df.head(10)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 10           11         1       3
# 11           12         0       1
# 13           14         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  36.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  18.0      1
# 2                              Heikkinen, Miss. Laina  female  14.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  27.0      1
# 4                            Allen, Mr. William Henry    male  63.0      0
# 5                                    Moran, Mr. James    male  14.0      0
# 6                             McCarthy, Mr. Timothy J    male  39.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female  42.0      1
# 11                           Bonnell, Miss. Elizabeth  female  30.0      0
# 13                        Andersson, Mr. Anders Johan    male  43.0      1
#
#     Parch            Ticket     Fare Cabin Embarked
# 0       0         A/5 21171   7.2500   NaN        S
# 1       0          PC 17599  71.2833   C85        C
# 2       0  STON/O2. 3101282   7.9250   NaN        S
# 3       0            113803  53.1000  C123        S
# 4       0            373450   8.0500   NaN        S
# 5       0            330877   8.4583   NaN        Q
# 6       0             17463  51.8625   E46        S
# 10      1           PP 9549  16.7000    G6        S
# 11      0            113783  26.5500  C103        S
# 13      5            347082  31.2750   NaN        S

# %% [markdown]
# **Part C**: Determine the fraction of survivors from each passenger class.

# %%
first_survived = (df.loc[df['Pclass']==1, 'Survived'].sum())/df['Survived'].sum()
second_survived = (df.loc[df['Pclass']==2, 'Survived'].sum())/df['Survived'].sum()
third_survived = (df.loc[df['Pclass']==3, 'Survived'].sum())/df['Survived'].sum()
print("Fraction of first class that survived: "+str(first_survived))
print("Fraction of second class that survived: "+str(second_survived))
print("Fraction of third class that survived: "+str(third_survived))
# Out:
# Fraction of first class that survived: 0.3870967741935484
# Fraction of second class that survived: 0.25089605734767023
# Fraction of third class that survived: 0.36200716845878134

# %% [markdown]
# **Part D**: Compute the fraction of survivors according to class and gender.  Did men in first class or women in third class have a higher survival rate?

# %%
c = df.groupby(['Pclass','Sex','Survived'])
c.describe()
#honestly i got the numbers from the above line because I didn't have time
#to figure out the 'proper' way
#female first class survived rate etc
f1s = 72/75
m1s = 36/93
f2s = 54/58
m2s = 16/87
f3s = 62/(56+62)
m3s = 39/(244+39)
print(m1s)
print(f3s)
print("Women in third class were more likely to survive than men in first class")
# Out:
# 0.3870967741935484
# 0.5254237288135594
# Women in third class were more likely to survive than men in first class

# %% [markdown]
# **Part E**: How would you characterize the distribution of **AGE**? (By _characterize_ we mean that you should indicate whether the data are unimodal, bimodal, multimodal, symmetric, negatively skewed, positively skewed, etc.)  Make any necessary graphical summaries to justify your conclusion.

# %%
fig, ax = plt.subplots(figsize=(8,4))
df.hist(column="Age", ax=ax)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001A078A06EF0>], dtype=object)

# %% [markdown]
# The histogram above shows that the age distribution is unimodal positively skewed and centered around age 25 roughly.

# %% [markdown]
# **Part F**: Were the median and mean ages for females who survived higher or lower than for females who did not survive?

# %%
df.groupby(['Sex','Survived']).describe()
# Out:
#                    Age                                                      \
#                  count       mean        std   min   25%   50%   75%   max
# Sex    Survived
# female 0          63.0  28.922063  14.379097  0.42  21.5  29.0  36.0  59.0
#        1         188.0  28.405585  13.726947  0.75  20.0  26.0  35.0  80.0
# male   0         372.0  29.890672  14.882577  0.83  20.0  29.0  38.0  74.0
#        1          91.0  32.126374  14.653705  1.00  22.0  29.0  42.5  66.0
#
#                   Fare            ...  Pclass       SibSp                      \
#                  count       mean ...     75%  max  count      mean       std
# Sex    Survived                   ...
# female 0          63.0  24.080822 ...     3.0  3.0   63.0  1.190476  1.908023
#        1         188.0  48.051264 ...     3.0  3.0  188.0  0.531915  0.755757
# male   0         372.0  21.067134 ...     3.0  3.0  372.0  0.435484  1.122487
#        1          91.0  43.018865 ...     3.0  3.0   91.0  0.384615  0.645828
#
#
#                  min  25%  50%  75%  max
# Sex    Survived
# female 0         0.0  0.0  1.0  1.0  8.0
#        1         0.0  0.0  0.0  1.0  4.0
# male   0         0.0  0.0  0.0  0.0  8.0
#        1         0.0  0.0  0.0  1.0  4.0
#
# [4 rows x 48 columns]

# %% [markdown]
# For survived females -- median: 26, mean: 28.4<br>
# For dead females -- median: 29, mean: 28.9<br>
# So the median and the mean age for females who did not survive were both higher than those of females who did survive.

# %% [markdown]
# **Part G**: Do the data suggest class warfare, male chivalry, or some combination of both characteristics in the final hours aboard the Titanic?  Justify your conclusion based on the computations done above, or do any other analysis that you like, but be sure to clearly justify your conclusion.

# %% [markdown]
# The data strongly suggests that chivalry played a pretty large role in the final hours of the titanic. Women were in almost every case, significantly more likely to survive than a man was. For example, a man in first class was still less likely to survive than a woman from third class. However, this brings up another interesting point: class warfare. The data shows that first and third class were both equally likely to survive, but second class was less likely than both of those. This implies that there could potentially have been some class warfare going on in the final hours.

# %% [markdown]
# ### Problem 5 - Not anotter homework problem! :(
# ***
#
# Otters are undisputedly one of nature's most awesome animals. From a cursory Google Image Search of *baby otter* or *otters holding hands* or *otters water slide* this is easy to demonstrate.
#
# Because the CS Department was able to pull a few strings, we have obtained a dataset of sea otter behavior. For each otter studied, the dataset contains:
#
# - **hhrecord**: the otter's personal record for hand-holding (hours; 999)
# - **pawsize**: the size of the otter's paw (unspecified units; 999)
# - **floatation**: boolean, indicating whether the otter displayed leadership in floatation. (9)
# - **satscore**: the otter's projected SAT score percentile. (unclear why this was included; 99)
# - **height**: otter's height (unspecified units; 99)
# - **weight**: otter's weight (unspecified units; 999)
# - **urchins**: boolean, indicating whether the otter was observed eating urchins (9)
#
# All these data are included in the whitespace-delimited file `otters.data`

# %% [markdown]
# **Part A**: Create a clean data set that removes subjects if any observations on the subject are unknown.  Note that that collectors of the data set used values like $9$, $99$, $999$, to denote unknown values. Those values are listed parenthetically in the description above Store the modified data set in a Pandas DataFrame called dfOtters.

# %%
#import it
path = "otters.data"
o = pd.read_csv(path, delim_whitespace=True)

#cleaning
o['hhrecord'].replace('', np.nan, inplace=True)
o['pawsize'].replace('', np.nan, inplace=True)
o['floatation'].replace('', np.nan, inplace=True)
o['satscore'].replace('', np.nan, inplace=True)
o['height'].replace('', np.nan, inplace=True)
o['weight'].replace('', np.nan, inplace=True)
o['urchins'].replace('', np.nan, inplace=True)
#now drop empties
o.dropna(subset=['hhrecord'], inplace=True)
o.dropna(subset=['pawsize'], inplace=True)
o.dropna(subset=['floatation'], inplace=True)
o.dropna(subset=['satscore'], inplace=True)
o.dropna(subset=['height'], inplace=True)
o.dropna(subset=['weight'], inplace=True)
o.dropna(subset=['urchins'], inplace=True)
#print
o.head(5)
# Out:
#    hhrecord  pawsize  floatation  satscore  height  weight  urchins
# 0       120      284           0        27      62     100        0
# 1       113      282           0        33      64     135        0
# 2       128      279           0        28      64     115        1
# 3       123      999           0        36      69     190        0
# 4       108      282           0        23      67     125        1

# %% [markdown]
# **Part B**: Use the information in dfOtters to create a density histogram of the hand-holding records of otters who do not eat sea urchins (urchins=0) and another histogram placed directly below the first in the same graphics device for the hand-holding records of otters who do eat urchins (urchins=1).  Make the range of the horizontal axis $30$ to $180$ (hours) for both histograms.  Make sure to give each subplot titles and label axes.

# %%
# Initialize figure subplots
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(8,8))

#plot the non urchin eaters
o.loc[o["urchins"]==0].hist(column="hhrecord", ax=axes[0])

axes[0].set_title("Hand Holding Record For Otters That Don't Eat Urchins", fontsize=20)
axes[0].set_xlabel("Hand Holding (hours)", fontsize=16)
axes[0].set_ylabel("Frequency", fontsize=16)

#plot the non urchin eaters
o.loc[o["urchins"]==1].hist(column="hhrecord", ax=axes[1])

axes[1].set_title("Hand Holding Record For Otters That Do Eat Urchins", fontsize=20)
axes[1].set_xlabel("Hand Holding (hours)", fontsize=16)
axes[1].set_ylabel("Frequency", fontsize=16)
# Out:
# Text(0,0.5,'Frequency')

# %% [markdown]
# **Part C**: Based on the histograms in **Part B**, characterize the distribution of hand-holding records for both urchin and non-urchin eaters.

# %% [markdown]
# The distribution for hours spent holding hands both for otters that do eat urchins and for otters that don't eat urchins is unimodal. However, for otters that don't eat urchins, there is a slight positive skew.

# %% [markdown]
# **Part D**: What are the mean and median hand-holding record differences between otters who eat urchins and otters who don't?  Can you think of any reason not to use the mean as a measure of center to compare records for this problem?

# %%
y = o.loc[o["urchins"]==1]
n = o.loc[o["urchins"]==0]
print("Mean for otters who do eat urchins: "+str(y['hhrecord'].mean()))
print("Mean for otters who dont eat urchins: "+str(n['hhrecord'].mean()))
# Out:
# Mean for otters who do eat urchins: 114.10950413223141
# Mean for otters who dont eat urchins: 123.04716981132076

# %% [markdown]
# There could be a lot of outliers for one group, which is actually shown in the next part E. The non-urchin-eaters group has a lot of outliers, which means the mean might not be the most accurate measure.

# %% [markdown]
# **Part E**: Create side-by-side box-and-whisker plots to compare the hand-holding records of otters who eat urchins and otters who do not.  Use the box-and-whisker plot conventions discussed in lecture.

# %%
# Initialize figure 
fig, ax = plt.subplots(figsize=(6,8))

#from the box plot assignment thing
ob = o.loc[(o["urchins"]==0) | (o["urchins"]==1)].boxplot(
    column=["hhrecord"], by="urchins", ax=ax, widths=[.5, .5], return_type="dict")
# Out:
# C:\Users\Vail Dorchester\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %% [markdown]
# **Part F**: Using the box-and-whisker plots from **Part E** comment on the distributions of hand-holding records of otters within each urchin / non-urchin groups as well as the comparison of the two classes.

# %% [markdown]
# In general, the otters who do not eat urchins hold hands slightly more. The mean is a bit higher, the median is higher, and Q1, Q2, and Q3 are all higher. The distribution for otters that do not eat urchins also includes mour outliers, and seems to be more evenly spread than that of the otters that do eat urchins, which exhibits a somewhat positive skew.

# %% [markdown]
# ### Problem 6: Cleaning Election Results Data
# ***
#
# The file 2014\_election\_results.csv contains data from congressional district races during the 2014 midterm elections.  The problem is that the data is **extremely dirty**.  Your goal in the problem will be to use Pandas to clean the election result data and then, if possible, determine the names of the winners in each congressional district as well as the vote percentage margin that they won by.  Remember that data cleaning and wrangling is a messy business.  Don't be afraid to roll your sleeves up and get hacky!
#
# **Part A**: Complete the clean_election_data( ) function to return a clean DataFrame that accomplishes the following:
#
# - remove rows in the DataFrame that are missing values in columns **STATE**, **D**, and/or **GENERAL PERCENT**
#
# <p> </p>
#
# - replace unknown names in **CANDIDATE NAME** with:
#     - the value from **CANDIDATE NAME (Last)**, if available
#     - the string "UNKNOWN" if impossible to determine the full or last name
#     - **Note**: besides "NaN", data collectors appear to have used the string "Scattered" to indicate missing names as well
# <p> </p>
# - convert the strings in **GENERAL PERCENT** to values of type float between $0$ and $100$
# <p> </p>
# - restrict the DataFrame to only the columns **STATE**, **D**, **CANDIDATE NAME**, **GENERAL PERCENT**

# %%
def clean_election_data():
    '''
    Function to clean election data 
    '''
    # read in dirty data 
    df = pd.read_csv("2014_election_results.csv")
    
    #1
    for index, row in df.iterrows():
        if pd.isnull(row['STATE']) or pd.isnull(row['D']) or pd.isnull(row['GENERAL PERCENT']):
            df.drop(index)
    #2
        if pd.isnull(row['CANDIDATE NAME']) or row['CANDIDATE NAME']=='Scattered':#if this is empty or scattered
            
            if pd.isnull(row['CANDIDATE NAME (Last)'])==False and row['CANDIDATE NAME (Last)'] != 'Scattered': #if this is not empty
                df.set_value(index, 'CANDIDATE NAME', row['CANDIDATE NAME (Last)'])
            else:
                df.set_value(index, 'CANDIDATE NAME', "UNKNOWN")
    #3
        old = str(row['GENERAL PERCENT'])
        x = old.replace(",", ".")
        y= x.replace("%", "")
        myF= float(y)
        df.set_value(index, 'GENERAL PERCENT', myF)
                
    dfClean=df[['STATE','D','CANDIDATE NAME','GENERAL PERCENT']]
    return dfClean

clean_election_data()
# Out:
#           STATE    D          CANDIDATE NAME GENERAL PERCENT
# 0       Alabama    1          Byrne, Bradley           68.16
# 1       Alabama    1      LeFlore, Burton R.           31.71
# 2       Alabama    1                 UNKNOWN            0.13
# 3       Alabama    1                 UNKNOWN             NaN
# 4       Alabama  NaN                 UNKNOWN             NaN
# 5       Alabama    2            Roby, Martha           67.34
# 6       Alabama    2                  Wright           32.56
# 7       Alabama    2                 UNKNOWN            0.09
# 8       Alabama    2                 UNKNOWN             NaN
# 9       Alabama  NaN                 UNKNOWN             NaN
# 10      Alabama    3            Rogers, Mike           66.12
# 11      Alabama    3          Casson, Thomas             NaN
# 12      Alabama    3                 UNKNOWN             NaN
# 13      Alabama    3         Smith, Jesse T.           33.72
# 14      Alabama    3                 UNKNOWN            0.16
# 15      Alabama    3                 UNKNOWN             NaN
# 16      Alabama  NaN                 UNKNOWN             NaN
# 17      Alabama    4        Aderholt, Robert           98.57
# 18      Alabama    4                 UNKNOWN            1.43
# 19      Alabama    4                 UNKNOWN             NaN
# 20      Alabama  NaN                 UNKNOWN             NaN
# 21      Alabama    5              Brooks, Mo           74.42
# 22      Alabama    5             Hill, Jerry             NaN
# 23      Alabama    5                 UNKNOWN             NaN
# 24      Alabama    5              Bray, Mark           25.17
# 25      Alabama    5                 UNKNOWN            0.41
# 26      Alabama    5                 UNKNOWN             NaN
# 27      Alabama  NaN                 UNKNOWN             NaN
# 28      Alabama    6            Palmer, Gary           76.18
# 29      Alabama    6           DeMarco, Paul             NaN
# ...         ...  ...                     ...             ...
# 3680  Wisconsin    7             Taylor, Rob            0.01
# 3681  Wisconsin    7                 UNKNOWN            0.01
# 3682  Wisconsin    7                 UNKNOWN             NaN
# 3683  Wisconsin  NaN                 UNKNOWN             NaN
# 3684  Wisconsin    8         Ribble, Reid J.           65.01
# 3685  Wisconsin    8                 UNKNOWN             NaN
# 3686  Wisconsin    8                 UNKNOWN             NaN
# 3687  Wisconsin    8             Gruett, Ron           34.94
# 3688  Wisconsin    8                 UNKNOWN             NaN
# 3689  Wisconsin    8                 UNKNOWN             NaN
# 3690  Wisconsin    8                 UNKNOWN             NaN
# 3691  Wisconsin    8                 UNKNOWN             NaN
# 3692  Wisconsin    8                 UNKNOWN            0.05
# 3693  Wisconsin    8                 UNKNOWN             NaN
# 3694  Wisconsin  NaN                 UNKNOWN             NaN
# 3695  Wisconsin    H                 UNKNOWN             NaN
# 3696        NaN  NaN                 UNKNOWN             NaN
# 3697    Wyoming    0         Lummis, Cynthia           68.47
# 3698    Wyoming    0                Senteney             NaN
# 3699    Wyoming    0                 UNKNOWN             NaN
# 3700    Wyoming    0                 UNKNOWN             NaN
# 3701    Wyoming    0        Grayson, Richard            22.9
# 3702    Wyoming    0                 UNKNOWN             NaN
# 3703    Wyoming    0                 UNKNOWN             NaN
# 3704    Wyoming    0       Brubaker, Richard            4.31
# 3705    Wyoming    0  Cummings, Daniel Clyde            4.09
# 3706    Wyoming    0                 UNKNOWN            0.24
# 3707    Wyoming    0                 UNKNOWN             NaN
# 3708    Wyoming    H                 UNKNOWN             NaN
# 3709    Wyoming  NaN                 UNKNOWN             NaN
#
# [3710 rows x 4 columns]

# %%
# read in dirty data
d = pd.read_csv("2014_election_results.csv")
d.head()
# Out:
#   STATE ABBREVIATION    STATE    D    FEC ID#  (I) CANDIDATE NAME (First)  \
# 0                 AL  Alabama    1  H4AL01123  (I)                Bradley
# 1                 AL  Alabama    1  H4AL01156  NaN              Burton R.
# 2                 AL  Alabama    1        n/a  NaN                    NaN
# 3                 AL  Alabama    1        n/a  NaN                    NaN
# 4                 AL  Alabama  NaN        n/a  NaN                    NaN
#
#   CANDIDATE NAME (Last)      CANDIDATE NAME      TOTAL VOTES PARTY    ...     \
# 0                 Byrne      Byrne, Bradley              NaN     R    ...
# 1               LeFlore  LeFlore, Burton R.              NaN     D    ...
# 2                   NaN           Scattered              NaN     W    ...
# 3                   NaN                 NaN  District Votes:   NaN    ...
# 4                   NaN                 NaN              NaN   NaN    ...
#
#   RUNOFF VOTES RUNOFF % GENERAL VOTES  GENERAL PERCENT  \
# 0          NaN      NaN        103,758          68,16%
# 1          NaN      NaN         48,278          31,71%
# 2          NaN      NaN            198           0,13%
# 3          NaN      NaN        152,234             NaN
# 4          NaN      NaN            NaN             NaN
#
#   GE RUNOFF ELECTION VOTES (LA) GE RUNOFF ELECTION % (LA)  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN
#
#   COMBINED GE PARTY TOTALS (CT, NY, SC) COMBINED % (CT, NY, SC)  \
# 0                                   NaN                     NaN
# 1                                   NaN                     NaN
# 2                                   NaN                     NaN
# 3                                   NaN                     NaN
# 4                                   NaN                     NaN
#
#   GE WINNER INDICATOR FOOTNOTES
# 0                   W       NaN
# 1                 NaN       NaN
# 2                 NaN       NaN
# 3                 NaN       NaN
# 4                 NaN       NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# **Part B**: Complete the function winners_and_margins( ) that takes in your clean DataFrame from **Part A** and returns a DataFrame with one row per state-district pair and with columns **STATE**, **D**, **WINNER**, and **MARGIN** where
#
# - **STATE** and **D** are as defined in the original DataFrame
# <p> </p>
# - **WINNER** is the name of the candidate that had the largest general vote percentage (which may possibly be "UNKNOWN")
# <p> </p>
# - **MARGIN** is the difference between the winning general vote percentage and the second highest vote percentage.  If there is only one candidate in a particular district you should list the general vote percentage obtained by the sole candidate.
#
# <p> </p>
#
# Finally, your DataFrame should be **sorted from most contentious races to least contentious** (i.e. from smallest winning margin to the largest).

# %%
def winners_and_margins(df):
    
    dfWinners = df.groupby(['STATE', 'D']).sum()
    #dfWinners["WINNER"] = dfWinners.apply(lambda row: 1 if row["Sex"]=="male" else 0, axis=1)
    #dfWinners = dfWinners[['STATE','D']]
    return dfWinners

# %%
n = winners_and_margins(d)
n.head(30)
# Out:
#                                                              FEC ID#  \
# STATE          D
# Alabama        1                            H4AL01123H4AL01156n/an/a
#                2                            H0AL02087H4AL02071n/an/a
#                3                H2AL03032H4AL03053n/aH4AL03061n/an/a
#                4                                     H6AL04098n/an/a
#                5                H0AL05163H4AL05074n/aH4AL05082n/an/a
#                6   H4AL06098H4AL06080H2AL06126H4AL06072H4AL06106H...
#                7                         H0AL07086H4AL07096n/an/an/a
#                H                                                 n/a
# Alaska         0   H6AK00045H0AK00097H4AK00149H4AK00131n/aH4AK001...
#                H                                                 n/a
# American Samoa 0   H4AS00036H0AS00018H4AS00085H4AS00069H8AS00052H...
#                H                                                 n/a
# Arizona        1   H8AZ01104 n/aH0AZ01325 H4AZ01145 H4AZ01152 n/an/a
#                2   H2AZ08102 H4AZ02143 H4AZ02135 n/aH2AZ08094n/aH...
#                3     H2AZ07070 n/aH2AZ07146n/aH4AZ03075H4AZ03083 n/a
#                4            H0AZ01259 n/aH2AZ04143n/aH4AZ04099n/an/a
#                5                        H4AZ01038 n/aH4AZ05088n/an/a
#                6                         H4AZ06045n/aH2AZ05132n/an/a
#                7   H4AZ07043 H4AZ07068H2AZ02220 H4AZ07076n/aH6AZ0...
#                8                H4AZ04024H4AZ08066n/aH2AZ08151n/an/a
#                9   H2AZ09019 n/aH2AZ09035 H4AZ09023 n/aH4AZ02119n...
#                H                                                 n/a
# Arkansas       1                     H0AR01083H4AR01051 H4AR01069n/a
#                2   H4AR02141 H4AR02158 H4AR02166 n/aH4AR02133 H4A...
#                3                              H0AR03055 H4AR03057n/a
#                4   H4AR04048 H4AR04055 n/aH4AR04063 H4AR04071H4AR...
#                H                                                 n/a
# California     1             H2CA02142H4CA01066H2CA01136H4CA01074n/a
#                10            H0CA19173H4CA10075H2CA00096H0CA11360n/a
#                11  H0CA10073H4CA11107H2CA11168H4CA11115H4CA11131H...
#
#                              STATE ABBREVIATION
# STATE          D
# Alabama        1                       ALALALAL
#                2                       ALALALAL
#                3                   ALALALALALAL
#                4                         ALALAL
#                5                   ALALALALALAL
#                6       ALALALALALALALALALALALAL
#                7                     ALALALALAL
#                H                             AL
# Alaska         0       AKAKAKAKAKAKAKAKAKAKAKAK
#                H                             AK
# American Samoa 0             ASASASASASASASASAS
#                H                             AS
# Arizona        1                 AZAZAZAZAZAZAZ
#                2             AZAZAZAZAZAZAZAZAZ
#                3                 AZAZAZAZAZAZAZ
#                4                 AZAZAZAZAZAZAZ
#                5                     AZAZAZAZAZ
#                6                     AZAZAZAZAZ
#                7   AZAZAZAZAZAZAZAZAZAZAZAZAZAZ
#                8                   AZAZAZAZAZAZ
#                9               AZAZAZAZAZAZAZAZ
#                H                             AZ
# Arkansas       1                       ARARARAR
#                2               ARARARARARARARAR
#                3                         ARARAR
#                4                 ARARARARARARAR
#                H                             AR
# California     1                     CACACACACA
#                10                    CACACACACA
#                11              CACACACACACACACA
